# %%
# Importing things 
import numpy as np
import pandas as pd 
import seaborn as sns

import matplotlib.pyplot as plt

import matplotlib.patches as mpatches

import matplotlib.ticker as mticker
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
from matplotlib.ticker import ScalarFormatter

import matplotlib.colors as colors
from matplotlib.colors import ListedColormap
from matplotlib.colors import LogNorm
from matplotlib.colors import Normalize

from scipy.ndimage import gaussian_filter

from matplotlib.gridspec import GridSpec

# %% [markdown]
# ## Plotting preferences

# %%
# Font sizes
axis_label_font = 30
axis_numbers_font = 25
title_font = 50
legend_font = 25

detection_colours = sns.color_palette("hls", 4)
dark_colours = sns.color_palette("viridis", 8)
my_colours = sns.color_palette("husl", 8)

cmap_reds = ListedColormap(plt.cm.get_cmap('Reds', 10)(np.arange(10)))
cmap_greens = ListedColormap(plt.cm.get_cmap('Greens', 10)(np.arange(10)))
cmap_purples = ListedColormap(plt.cm.get_cmap('Purples', 10)(np.arange(10)))

alpha = 0.7

path = '/Users/audreyburggraf/Desktop/THESIS/Figures/'

# %% [markdown]
# ## Data

# %%
# Importing data file 
df = pd.read_csv('/Users/audreyburggraf/Desktop/THESIS/Data Files/bigrun_10000_after_changes.csv')

df['m_p'] = 10**df['Inj.1P log(m_p)']

# cut off certain range 
df_JupiterAnalog = df[(0.3 <= df.m_p) & (df.m_p <= 3)].reset_index(drop=True)
df_JupiterMass = df[(0.9 <= df.m_p) & (df.m_p <= 1.1)].reset_index(drop=True)

# %%
len(df_JupiterMass)
# Out:
# 546

# %%
df_JupiterMass['Detection'].sum()
# Out:
# 3

# %% [markdown]
# ## Bins

# %%
MpBin = np.logspace(np.log10(df['m_p'].min()), np.log10(df['m_p'].max()), 20) 
MpBin_JupiterAnalog = np.logspace(np.log10(df_JupiterAnalog['m_p'].min()), np.log10(df_JupiterAnalog['m_p'].max()), 20) 
MpBin_JupiterMass = np.logspace(np.log10(df_JupiterMass['m_p'].min()), np.log10(df_JupiterMass['m_p'].max()), 20) 


num_MpBin = len(MpBin) - 1
num_MpBin_JupiterAnalog = len(MpBin_JupiterAnalog) - 1
num_MpBin_JupiterMass = len(MpBin_JupiterMass) - 1

MpBin_midpoints = (MpBin[:-1] + MpBin[1:]) / 2
MpBin_midpoints_JupiterAnalog = (MpBin_JupiterAnalog[:-1] + MpBin_JupiterAnalog[1:]) / 2
MpBin_midpoints_JupiterMass = (MpBin_JupiterMass[:-1] + MpBin_JupiterMass[1:]) / 2

# %%
Mp_detection = []
Mp_detection_uncertainty = []

Mp_detection_JupiterAnalog = []
Mp_detection_uncertainty_JupiterAnalog = []

Mp_detection_JupiterMass = []
Mp_detection_uncertainty_JupiterMass = []

# %% [markdown]
# # Full Data Frame

# %%
# Iterate over each bin of S/N values
for i in range(len(MpBin)):

    # Filter the DataFrame for S/N values within the current bin range
    filtered_df = df[(df['m_p'] > MpBin[i])]

    # Calculate detection fraction as the fraction of detected samples
    num_detected = filtered_df['Detection'].sum()
    num_samples = len(filtered_df)
    detection_fraction = num_detected / num_samples
    detection_fraction_uncertainty = np.sqrt(num_detected) / num_samples
    
    # Append the detection fraction to the new list
    Mp_detection.append(detection_fraction)
    Mp_detection_uncertainty.append(detection_fraction_uncertainty)
    
    print(f"For Mp > {MpBin[i]:.3f}, sensitivity to detection fraction: {detection_fraction:.2f} ± {detection_fraction_uncertainty:.2f}")
# Out:
# For Mp > 0.300, sensitivity to detection fraction: 0.15 ± 0.00
# For Mp > 0.366, sensitivity to detection fraction: 0.16 ± 0.00
# For Mp > 0.446, sensitivity to detection fraction: 0.17 ± 0.00
# For Mp > 0.544, sensitivity to detection fraction: 0.18 ± 0.00
# For Mp > 0.664, sensitivity to detection fraction: 0.19 ± 0.00
# For Mp > 0.809, sensitivity to detection fraction: 0.20 ± 0.01
# For Mp > 0.987, sensitivity to detection fraction: 0.22 ± 0.01
# For Mp > 1.203, sensitivity to detection fraction: 0.23 ± 0.01
# For Mp > 1.467, sensitivity to detection fraction: 0.25 ± 0.01
# For Mp > 1.789, sensitivity to detection fraction: 0.27 ± 0.01
# For Mp > 2.181, sensitivity to detection fraction: 0.29 ± 0.01
# For Mp > 2.659, sensitivity to detection fraction: 0.30 ± 0.01
# For Mp > 3.243, sensitivity to detection fraction: 0.32 ± 0.01
# For Mp > 3.954, sensitivity to detection fraction: 0.33 ± 0.01
# For Mp > 4.822, sensitivity to detection fraction: 0.35 ± 0.01
# For Mp > 5.879, sensitivity to detection fraction: 0.37 ± 0.01
# For Mp > 7.169, sensitivity to detection fraction: 0.38 ± 0.02
# For Mp > 8.742, sensitivity to detection fraction: 0.41 ± 0.02
# For Mp > 10.660, sensitivity to detection fraction: 0.43 ± 0.03
# For Mp > 12.998, sensitivity to detection fraction: nan ± nan
# /var/folders/p9/hcwv87bd7lxfdw1nmx4wt8d00000gn/T/ipykernel_97404/1671783836.py:10: RuntimeWarning: invalid value encountered in long_scalars
#   detection_fraction = num_detected / num_samples
# /var/folders/p9/hcwv87bd7lxfdw1nmx4wt8d00000gn/T/ipykernel_97404/1671783836.py:11: RuntimeWarning: invalid value encountered in double_scalars
#   detection_fraction_uncertainty = np.sqrt(num_detected) / num_samples

# %%
# Create a figure and axes
fig, ax = plt.subplots(figsize=(13, 10))

# Plot the sensitivity values as a bar graph

plt.plot(MpBin, 
         Mp_detection, 
         marker='o', 
         ms = 10,
         lw = 5, 
         linestyle='-',
         color=my_colours[5], 
         alpha=alpha)


plt.axhline(y=0.5, color='red', linestyle='--', lw = 3, label='Horizontal Line at y=0.5')


# Axes labels 
ax.set_xlabel('$S/N$', fontsize=axis_label_font)
ax.set_ylabel('Detection Fraction for $S/N>x$', fontsize=axis_label_font)

# add legned
# ax.legend(fontsize=legend_font)

ax.set_xscale('log')


# Formatting axes labels to avoid scientific notation
# ax.xaxis.set_major_formatter(ScalarFormatter(useMathText=True))
# ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))

# Set x-axis tick parameters
ax.tick_params(labelsize=axis_numbers_font, which='major', length=7)
ax.tick_params(which='minor', length=4)

# plt.savefig(path + 'SN_xgeq_.pdf', dpi=300)

# %% [markdown]
# # Jupiter Analog

# %%
# Iterate over each bin of S/N values
for i in range(len(MpBin_JupiterAnalog)):
    # Filter the DataFrame for S/N values within the current bin range
    filtered_df = df_JupiterAnalog[df_JupiterAnalog['m_p'] > MpBin_JupiterAnalog[i]]

    # Calculate detection fraction as the fraction of detected samples
    num_detected = filtered_df['Detection'].sum()
    num_samples = len(filtered_df)
    detection_fraction_JupiterAnalog = num_detected / num_samples
    
    # Calculate uncertainty in detection fraction
    detection_fraction_uncertainty_JupiterAnalog = np.sqrt(num_detected) / num_samples
    
    # Append the detection fraction and uncertainty to the respective lists
    Mp_detection_JupiterAnalog.append(detection_fraction_JupiterAnalog)
    Mp_detection_uncertainty_JupiterAnalog.append(detection_fraction_uncertainty_JupiterAnalog)
    
    print(f"For Mp > {MpBin_JupiterAnalog[i]:.3f}, sensitivity to detection fraction: {detection_fraction_JupiterAnalog*100:.2f} ± {detection_fraction_uncertainty_JupiterAnalog:.2f}")
# Out:
# For Mp > 0.300, sensitivity to detection fraction: 5.24 ± 0.00
# For Mp > 0.339, sensitivity to detection fraction: 5.44 ± 0.00
# For Mp > 0.382, sensitivity to detection fraction: 5.61 ± 0.00
# For Mp > 0.432, sensitivity to detection fraction: 5.88 ± 0.00
# For Mp > 0.487, sensitivity to detection fraction: 6.21 ± 0.00
# For Mp > 0.550, sensitivity to detection fraction: 6.42 ± 0.00
# For Mp > 0.621, sensitivity to detection fraction: 6.77 ± 0.00
# For Mp > 0.701, sensitivity to detection fraction: 7.26 ± 0.00
# For Mp > 0.791, sensitivity to detection fraction: 7.70 ± 0.00
# For Mp > 0.893, sensitivity to detection fraction: 8.29 ± 0.01
# For Mp > 1.008, sensitivity to detection fraction: 9.15 ± 0.01
# For Mp > 1.137, sensitivity to detection fraction: 10.24 ± 0.01
# For Mp > 1.284, sensitivity to detection fraction: 11.26 ± 0.01
# For Mp > 1.449, sensitivity to detection fraction: 12.07 ± 0.01
# For Mp > 1.636, sensitivity to detection fraction: 13.03 ± 0.01
# For Mp > 1.846, sensitivity to detection fraction: 13.73 ± 0.01
# For Mp > 2.084, sensitivity to detection fraction: 15.72 ± 0.01
# For Mp > 2.352, sensitivity to detection fraction: 14.95 ± 0.02
# For Mp > 2.655, sensitivity to detection fraction: 16.29 ± 0.02
# For Mp > 2.997, sensitivity to detection fraction: nan ± nan
# /var/folders/p9/hcwv87bd7lxfdw1nmx4wt8d00000gn/T/ipykernel_97404/3751861752.py:9: RuntimeWarning: invalid value encountered in long_scalars
#   detection_fraction_JupiterAnalog = num_detected / num_samples
# /var/folders/p9/hcwv87bd7lxfdw1nmx4wt8d00000gn/T/ipykernel_97404/3751861752.py:12: RuntimeWarning: invalid value encountered in double_scalars
#   detection_fraction_uncertainty_JupiterAnalog = np.sqrt(num_detected) / num_samples

# %%
# Create a figure and axes
fig, ax = plt.subplots(figsize=(13, 10))

# Plot the sensitivity values as a bar graph

plt.plot(MpBin_JupiterAnalog, 
         Mp_detection_JupiterAnalog, 
         marker='o', 
         ms = 10,
         lw = 5, 
         linestyle='-',
         color=my_colours[5], 
         alpha=alpha)


plt.axhline(y=0.5, color='red', linestyle='--', lw = 3, label='Horizontal Line at y=0.5')


# Axes labels 
ax.set_xlabel('$Mp$', fontsize=axis_label_font)
ax.set_ylabel('Detection Fraction for $Mp>x$', fontsize=axis_label_font)

# add legned
# ax.legend(fontsize=legend_font)

ax.set_xscale('log')


# Formatting axes labels to avoid scientific notation
ax.xaxis.set_major_formatter(ScalarFormatter(useMathText=True))
# ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))

# Set x-axis tick parameters
ax.tick_params(labelsize=axis_numbers_font, which='major', length=7)
ax.tick_params(which='minor', length=4)

# plt.savefig(path + 'SN_xgeq_.pdf', dpi=300)

# %% [markdown]
# # Jupiter Mass

# %%
# Iterate over each bin of S/N values
for i in range(len(MpBin_JupiterMass)):
    # Filter the DataFrame for S/N values within the current bin range
    filtered_df = df_JupiterMass[df_JupiterMass['m_p'] > MpBin_JupiterMass[i]]

    # Calculate detection fraction as the fraction of detected samples
    num_detected = filtered_df['Detection'].sum()
    num_samples = len(filtered_df)
    detection_fraction_JupiterMass = num_detected / num_samples
    
    # Calculate uncertainty in detection fraction
    detection_fraction_uncertainty_JupiterMass = np.sqrt(num_detected) / num_samples
    
    # Append the detection fraction and uncertainty to the respective lists
    Mp_detection_JupiterMass.append(detection_fraction_JupiterMass)
    Mp_detection_uncertainty_JupiterMass.append(detection_fraction_uncertainty_JupiterMass)
    
    print(f"For Mp > {MpBin_JupiterMass[i]:.3f}, sensitivity to detection fraction: {detection_fraction_JupiterMass*100:.0f} ± {detection_fraction_uncertainty_JupiterMass:.2f}")
# Out:
# For Mp > 0.900, sensitivity to detection fraction: 1 ± 0.00
# For Mp > 0.910, sensitivity to detection fraction: 1 ± 0.00
# For Mp > 0.919, sensitivity to detection fraction: 1 ± 0.00
# For Mp > 0.929, sensitivity to detection fraction: 1 ± 0.00
# For Mp > 0.939, sensitivity to detection fraction: 1 ± 0.00
# For Mp > 0.949, sensitivity to detection fraction: 1 ± 0.00
# For Mp > 0.959, sensitivity to detection fraction: 1 ± 0.00
# For Mp > 0.969, sensitivity to detection fraction: 1 ± 0.01
# For Mp > 0.979, sensitivity to detection fraction: 1 ± 0.01
# For Mp > 0.990, sensitivity to detection fraction: 1 ± 0.01
# For Mp > 1.000, sensitivity to detection fraction: 1 ± 0.01
# For Mp > 1.011, sensitivity to detection fraction: 0 ± 0.00
# For Mp > 1.021, sensitivity to detection fraction: 0 ± 0.00
# For Mp > 1.032, sensitivity to detection fraction: 1 ± 0.01
# For Mp > 1.043, sensitivity to detection fraction: 1 ± 0.01
# For Mp > 1.054, sensitivity to detection fraction: 0 ± 0.00
# For Mp > 1.065, sensitivity to detection fraction: 0 ± 0.00
# For Mp > 1.077, sensitivity to detection fraction: 0 ± 0.00
# For Mp > 1.088, sensitivity to detection fraction: 0 ± 0.00
# For Mp > 1.100, sensitivity to detection fraction: nan ± nan
# /var/folders/p9/hcwv87bd7lxfdw1nmx4wt8d00000gn/T/ipykernel_97404/4135734004.py:9: RuntimeWarning: invalid value encountered in long_scalars
#   detection_fraction_JupiterMass = num_detected / num_samples
# /var/folders/p9/hcwv87bd7lxfdw1nmx4wt8d00000gn/T/ipykernel_97404/4135734004.py:12: RuntimeWarning: invalid value encountered in double_scalars
#   detection_fraction_uncertainty_JupiterMass = np.sqrt(num_detected) / num_samples

# %%
# Create a figure and axes
fig, ax = plt.subplots(figsize=(13, 10))

# Plot the sensitivity values as a bar graph

plt.plot(MpBin_JupiterMass, 
         Mp_detection_JupiterMass, 
         marker='o', 
         ms = 10,
         lw = 5, 
         linestyle='-',
         color=my_colours[5], 
         alpha=alpha)


plt.axhline(y=0.5, color='red', linestyle='--', lw = 3, label='Horizontal Line at y=0.5')


# Axes labels 
ax.set_xlabel('$Mp$', fontsize=axis_label_font)
ax.set_ylabel('Detection Fraction for $Mp>x$', fontsize=axis_label_font)

# add legned
# ax.legend(fontsize=legend_font)

ax.set_xscale('log')


# Formatting axes labels to avoid scientific notation
ax.xaxis.set_major_formatter(ScalarFormatter(useMathText=True))
# ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))

# Set x-axis tick parameters
ax.tick_params(labelsize=axis_numbers_font, which='major', length=7)
ax.tick_params(which='minor', length=4)

# plt.savefig(path + 'SN_xgeq_.pdf', dpi=300)
